# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pandas as pd

# %%
comments = pd.read_csv("2021-09-24-09.csv")
comments.head(34)
# Out:
#     Unnamed: 0 stars     title  \
# 0            0     3  no_title
# 1            1     5  no_title
# 2            2     5  no_title
# 3            3     5  no_title
# 4            4     5  no_title
# 5            5     5  no_title
# 6            6     4  no_title
# 7            7     4  no_title
# 8            8     1  no_title
# 9            9     4  no_title
# 10          10     5  no_title
# 11          11     1  no_title
# 12          12     5  no_title
# 13          13     5  no_title
# 14          14     5  no_title
# 15          15     5  no_title
# 16          16     2  no_title
# 17          17     4  no_title
# 18          18     1  no_title
# 19          19     4  no_title
# 20          20     5  no_title
# 21          21     5  no_title
# 22          22     5  no_title
# 23          23     5  no_title
# 24          24     5  no_title
# 25          25     3  no_title
# 26          26     5  no_title
# 27          27     5  no_title
# 28          28     5  no_title
# 29          29     5  no_title
# 30          30     5  no_title
# 31          31     4  no_title
# 32          32     5  no_title
# 33          33     4  no_title
#
#                                                  body  \
# 0                        Good product and good value.
# 1   Bought to try for daughter that has trouble sw...
# 2   Nothing bad to say about this product.  It wor...
# 3   It does exactly what it is supposed to do. Thi...
# 4   Mixes well with liquids when you make this it ...
# 5            It does what it is supposed to do. Well.
# 6                                               good.
# 7   The product works well for my needs.  The cont...
# 8   This product was given by my pharmacy in place...
# 9   Easy to use...I'd use less product than they s...
# 10  I have a grandson that is  a total invalid and...
# 11  I tried putting it in yogurt, but it gave the ...
# 12                                     Great Product.
# 13                           As good as it gets  !!!!
# 14  Order always arrives promptly. I order from Pr...
# 15  This product saves so much in the large size.d...
# 16                  Not really what I will buy again.
# 17                          It seems to do the trick.
# 18  The container I received has been working very...
# 19  Great for people who have trouble swallowing l...
# 20                                 Fast shipping!A+++
# 21                                  works really well
# 22  It works very good and I will order It again i...
# 23  My father 92+ needs this  to mix with water th...
# 24                                everything was fine
# 25  Works well with liquids, not so good with soli...
# 26  this stuff is great. I have a kitty I rescued ...
# 27                Yo lo utilizo para sopas y liquidos
# 28                         Great product came quickly
# 29                        Best for my elderly mother.
# 30                 Works as advertised, does the job.
# 31                     Good price and quick delivery.
# 32  It is exactly what I needed/wanted and was rec...
# 33  Thick-It works for those with swallowing diffi...
#
#                                                  date
# 0     Reviewed in the United States on August 8, 2014
# 1     Reviewed in the United States on April 20, 2021
# 2     Reviewed in the United States on March 19, 2021
# 3      Reviewed in the United States on April 7, 2021
# 4     Reviewed in the United States on March 27, 2021
# 5    Reviewed in the United States on August 30, 2014
# 6        Reviewed in the United States on May 2, 2016
# 7    Reviewed in the United States on August 29, 2017
# 8      Reviewed in the United States on July 19, 2012
# 9    Reviewed in the United States on August 11, 2017
# 10     Reviewed in the United States on July 17, 2016
# 11    Reviewed in the United States on April 26, 2017
# 12     Reviewed in the United States on June 16, 2016
# 13   Reviewed in the United States on August 22, 2016
# 14      Reviewed in the United States on July 6, 2016
# 15  Reviewed in the United States on January 10, 2012
# 16  Reviewed in the United States on September 25,...
# 17  Reviewed in the United States on December 13, ...
# 3  It is also a great price for that amount of pr...  20 May 2018
# 4  Easy to use, works fast We use this to thicken...  15 Aug 2018
#
#                                      variant images verified  \
# 0  Size: 2.25 Pound (Pack of 1) Style: 36 oz    NaN      Yes
# 1  Size: 2.25 Pound (Pack of 1) Style: 36 oz    NaN      Yes
# 2  Size: 2.25 Pound (Pack of 1) Style: 36 oz    NaN      Yes
# 3  Size: 2.25 Pound (Pack of 1) Style: 36 oz    NaN      Yes
# 4  Size: 2.25 Pound (Pack of 1) Style: 36 oz    NaN      Yes
#
#                 author  rating  \
# 0        Sandy Everett     5.0
# 1               Pam J.     4.0
# 2           tnectravel     5.0
# 3                   RS     5.0
# 4  Artful Celebrations     5.0
#
#                                              product  \
# 0  Thick-It Original Food & Beverage Thickener, 3...
# 1  Thick-It Original Food & Beverage Thickener, 3...
# 2  Thick-It Original Food & Beverage Thickener, 3...
# 3  Thick-It Original Food & Beverage Thickener, 3...
# 4  Thick-It Original Food & Beverage Thickener, 3...
#
#                                                  url
# 0  https://www.amazon.com/Thick-It-RD26929208-36-...
# 1  https://www.amazon.com/Thick-It-RD26929208-36-...
# 2  https://www.amazon.com/Thick-It-RD26929208-36-...
# 3  https://www.amazon.com/Thick-It-RD26929208-36-...
# 4  https://www.amazon.com/Thick-It-RD26929208-36-...

# %%
counts = [0,0,0,0,0]
for i in range(0, len(comments)):
    #if comments['rating'][i][0].isdigit():
     #   comments['rating'][i] = int(comments['rating'][i][0])
        counts[int(comments['rating'][i]) -1] += 1
    #else: 
    #    comments.drop([i])
#unsure why the comment out code sometimes works and sometimes doesn't

# %%
counts
# Out:
# [47, 0, 1, 93, 559]

# %%
labels = ['1', '2', '3', '4', '5']
plt.bar(labels, counts, color = '#EFA18A')
plt.title("Food Thickener Amazon Ratings")
plt.xlabel("rating")
plt.ylabel("count ")
# Out:
# Text(0, 0.5, 'count ')

# %%
text = ""
for comment in comments["content"]:
    text += (" " + comment)

wordcloud = WordCloud(width=2000, height=2000, margin=0, background_color = "white").generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
wordgraphx = plt.figure()
plt.show()
plt.savefig('wordcloud.png')

# %%
#Import packages
import pandas as pd
import re, string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
from textblob import TextBlob
sw = stopwords.words('english')

# %%
#The function
def clean_text(text):
    text = text.lower()
    text = re.sub('@', '', text)
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(r"[^a-zA-Z ]+", "", text)
    
    #Tokenize the data
    text = nltk.word_tokenize(text)
    #Remove stopwords
    text = [w for w in text if w not in sw]
    return text

# %%
comments['analysis'] = comments['analysis'].apply(lambda x: clean_text(x))

# %%
comments['analysis']
# Out:
# 0      [thick, swallow, disorder, used, thick, severa...
# 1      [recommend, currently, long, time, product, ch...
# 2      [thickit, odorless, tasteless, enjoy, drink, p...
# 3      [also, great, price, amount, product, get, com...
# 4      [easy, use, works, fast, use, thicken, drinks,...
#                              ...
# 768    [disabled, parent, used, years, best, value, q...
# 769    [new, look, thickit, bad, quality, thicker, ne...
# 770    [works, well, grainy, product, thickens, drink...
# 771    [pictured, product, exactly, like, give, skill...
# 772    [bug, found, thickener, product, even, close, ...
# Name: analysis, Length: 773, dtype: object

# %%
#Lemmatizer
lemmatizer = WordNetLemmatizer()
def lem(text):
    text = [lemmatizer.lemmatize(t) for t in text]
    text = [lemmatizer.lemmatize(t, 'v') for t in text]
    return text

# %%
nltk.download('wordnet')
comments['analysis'] = comments['analysis'].apply(lambda x: lem(x))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/brianzhang/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
comments['analysis']
# Out:
# 0      [thick, swallow, disorder, use, thick, several...
# 1      [recommend, currently, long, time, product, ch...
# 2      [thickit, odorless, tasteless, enjoy, drink, p...
# 3      [also, great, price, amount, product, get, com...
# 4      [easy, use, work, fast, use, thicken, drink, b...
#                              ...
# 768    [disable, parent, use, year, best, value, qual...
# 769    [new, look, thickit, bad, quality, thicker, ne...
# 770    [work, well, grainy, product, thicken, drink, ...
# 771    [picture, product, exactly, like, give, skille...
# 772    [bug, find, thickener, product, even, close, e...
# Name: analysis, Length: 773, dtype: object

# %%
#From lists of comments to a single list containing all words      
all_words=[]        
for i in range(len(comments)):
    all_words = all_words + comments['analysis'][i]
#Get word frequency        
nlp_words = nltk.FreqDist(all_words)
plot1 = nlp_words.plot(20, color='salmon', title='Word Frequency')

# %%
#Bigrams
bigrm = list(nltk.bigrams(all_words))
words_2 = nltk.FreqDist(bigrm)
words_2.plot(20, color='salmon', title='Bigram Frequeancy')
# Out:
# <AxesSubplot:title={'center':'Bigram Frequeancy'}, xlabel='Samples', ylabel='Counts'>

# %%
#Trigram
trigrm = list(nltk.trigrams(all_words))
words_2 = nltk.FreqDist(trigrm)
words_2.plot(20, color='salmon', title='Trigram Frequeancy')
# Out:
# <AxesSubplot:title={'center':'Trigram Frequeancy'}, xlabel='Samples', ylabel='Counts'>

# %%
#Get sentiment from comments
comments['analysis'] = [str(thing) for thing in comments['analysis']]
sentiment = []
for i in range(len(comments)):
    blob = TextBlob(comments['analysis'][i])
    for sentence in blob.sentences:
        sentiment.append(sentence.sentiment.polarity)
comments['analysis']=sentiment
#Plot
comments['analysis'].plot.hist(color='salmon', title='Comments Polarity')
# Out:
# <AxesSubplot:title={'center':'Comments Polarity'}, ylabel='Frequency'>

# %%
for i in range(0, len(comments)):
    if type(comments['rating'][i]) is not int: 
        print(comments['rating'][i])
# Out:
# 5.0
# 4.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 1.0
# 4.0
# 5.0
# 4.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 5.0
# 1.0
# 4.0
# 5.0
# 4.0
    if(comments['rating'][i] == 5 and comments["analysis"][i] < -0.16):
        print(comments["content"][i] + '\n')
#isn't working because the ratings are strins again...
# Out:
# So I bought this for the meme, I tried it in water, and it was terrible and disgusting, so then I tried it in orange juice, an it tasted like orange flavored apple sauce, so if you want to try this because why not, use it in juices and flavored drinks, it basically makes it into apple sauce, or liquid apple sauce depending on how much powder you use, also it makes liquids paste thick, it’s not smooth thick like honey, it’s like again, apple sauce, or a paste.
#
# So I bought this for the meme, I tried it in water, and it was terrible and disgusting, so then I tried it in orange juice, an it tasted like orange flavored apple sauce, so if you want to try this because why not, use it in juices and flavored drinks, it basically makes it into apple sauce, or liquid apple sauce depending on how much powder you use, also it makes liquids paste thick, it’s not smooth thick like honey, it’s like again, apple sauce, or a paste.
#
# So I bought this for the meme, I tried it in water, and it was terrible and disgusting, so then I tried it in orange juice, an it tasted like orange flavored apple sauce, so if you want to try this because why not, use it in juices and flavored drinks, it basically makes it into apple sauce, or liquid apple sauce depending on how much powder you use, also it makes liquids paste thick, it’s not smooth thick like honey, it’s like again, apple sauce, or a paste.
#
# So I bought this for the meme, I tried it in water, and it was terrible and disgusting, so then I tried it in orange juice, an it tasted like orange flavored apple sauce, so if you want to try this because why not, use it in juices and flavored drinks, it basically makes it into apple sauce, or liquid apple sauce depending on how much powder you use, also it makes liquids paste thick, it’s not smooth thick like honey, it’s like again, apple sauce, or a paste.
#
# So I bought this for the meme, I tried it in water, and it was terrible and disgusting, so then I tried it in orange juice, an it tasted like orange flavored apple sauce, so if you want to try this because why not, use it in juices and flavored drinks, it basically makes it into apple sauce, or liquid apple sauce depending on how much powder you use, also it makes liquids paste thick, it’s not smooth thick like honey, it’s like again, apple sauce, or a paste.
#
# So I bought this for the meme, I tried it in water, and it was terrible and disgusting, so then I tried it in orange juice, an it tasted like orange flavored apple sauce, so if you want to try this because why not, use it in juices and flavored drinks, it basically makes it into apple sauce, or liquid apple sauce depending on how much powder you use, also it makes liquids paste thick, it’s not smooth thick like honey, it’s like again, apple sauce, or a paste.
#
# So I bought this for the meme, I tried it in water, and it was terrible and disgusting, so then I tried it in orange juice, an it tasted like orange flavored apple sauce, so if you want to try this because why not, use it in juices and flavored drinks, it basically makes it into apple sauce, or liquid apple sauce depending on how much powder you use, also it makes liquids paste thick, it’s not smooth thick like honey, it’s like again, apple sauce, or a paste.
#
# Very impressed with the amount per case. Was a little disappointed in the length of time it took to be delivered. Will be reordering. Thanks.

# %%
for i in range(0, len(comments)):
    if(comments['rating'][i] == 5 and comments["analysis"][i] < -0.16):
        print(i)
# Out:
# 621
# 631
# 641
# 651
# 661
# 671
# 681
# 693

# %% [markdown]
# Because the food thickener is a product intended for people with issues consuming food, the sentiment analyis is unable tell apart descrptions of the user's condition (with words such as choke, issues, etc). Thus, the connotation associated with these conditions is often factored into the user's overall positive review.Some alos referenced factors outside the scope of the product suchas the delivery time.

# %% [markdown]
# https://towardsdatascience.com/using-nlp-to-figure-out-what-people-really-think-e1d10d98e491
# link to the code that was used in the previous sections

# %% [markdown]
# trying other methods of visualization data
